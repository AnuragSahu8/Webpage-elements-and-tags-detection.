# %%
# !pip install ultralytics
# Out:
# ...
#      -------------------------------------- 723.1/723.1 kB 2.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 198.5/198.5 MB 2.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 4.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image,display

# %% [markdown]
# # Model training

# %%
model = YOLO('yolov8s.pt')

# Train the model
results = model.train(data='data.yaml', epochs=100, imgsz=224)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 21.5M/21.5M [00:09<00:00, 2.28MB/s]
# Ultralytics YOLOv8.1.33 🚀 Python-3.9.13 torch-2.2.1+cpu CPU (11th Gen Intel Core(TM) i5-11260H 2.60GHz)
# ...

# %%
model = YOLO("../runs/detect/train/weights/best.pt")
validation_results = model.val(data='data.yaml',plots=True,conf=0.25)
# Out:
# Ultralytics YOLOv8.1.33 🚀 Python-3.9.13 torch-2.2.1+cpu CPU (11th Gen Intel Core(TM) i5-11260H 2.60GHz)
# Model summary (fused): 168 layers, 11130228 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning C:\Users\Dell\YoloV8\Assigment\valid\labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████|
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          8         76      0.299      0.229      0.271      0.195
#                  Image          8          1          0          0          0          0
#        Navigation-dots          8          1          0          0          0          0
#                buttons          8         23        0.7      0.304      0.532      0.344
#               checkbox          8          5          0          0          0          0
#               dropdown          8          3          0          0          0          0
# ...

# %% [markdown]
# # Metrics Evaluation

# %%
Image(filename="../Assigment/runs/detect/train/results.png")

# %% [markdown]
# # Batch predicted Images on val Data

# %%
Image("../Assigment/runs/detect/val2/val_batch0_labels.jpg")

# %% [markdown]
# # Prediction on New Image

# %%
Image("1.jpg")

# %%
from ultralytics import YOLO
model=YOLO("../Assigment/runs/detect/train/weights/best.pt")

# %%
results=model("1.jpg")

for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='result_1.jpg')
# Out:
# image 1/1 C:\Users\Dell\YoloV8\Assigment\1.jpg: 224x224 1 buttons, 6 input-fieldss, 1 text, 39.7ms
# Speed: 0.0ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
Image("result_1.jpg")

# %%
Image("2.jpg")

# %%
results=model("2.jpg")
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
#     result.save(filename='result_2.jpg')
# Out:
# image 1/1 C:\Users\Dell\YoloV8\Assigment\2.jpg: 192x224 1 Image, 8 buttonss, 1 text, 218.1ms
# Speed: 2.0ms preprocess, 218.1ms inference, 13.0ms postprocess per image at shape (1, 3, 192, 224)

# %% [markdown]
# # Real Time Object Detection using webcam

# %%
from ultralytics import YOLO

model=YOLO("../Assigment/runs/detect/train/weights/best.pt")

result=model.predict(source="1",conf=0.25,save=False,show=True)
# Out:
# 1/1: 1... Success ✅ (inf frames of shape 640x480 at 29.97 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 192x224 (no detections), 153.7ms
# 0: 192x224 (no detections), 223.0ms
# 0: 192x224 (no detections), 140.8ms
# 0: 192x224 (no detections), 145.8ms
# 0: 192x224 (no detections), 139.1ms
# 0: 192x224 (no detections), 141.8ms
# 0: 192x224 (no detections), 145.4ms
# 0: 192x224 (no detections), 139.0ms
# 0: 192x224 (no detections), 144.8ms
# ...
